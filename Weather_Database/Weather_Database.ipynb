# %%
import pandas as pd
import numpy as np
from citipy import citipy

# %%
from config import weather_api_key

# %%
import requests

# %%
# Create a new set of 2,0000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name


    if city not in cities:
        cities.append(city)

# %%
# Ge the nearest city using the citipy module
print(city)
# Out:
# kvareli

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")


record_count = 1
set_count = 1


for i, city in enumerate(cities):
    
 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + '&q=' + city.replace(" ","+")
    
    
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    record_count += 1
    
    # Retrieve the following information from the API call:
    try:
        
        city_weather = requests.get(city_url).json()
        
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})


    except:
        print("City not found. Skipping...")
        pass


print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | constantine
# Processing Record 2 of Set 1 | morondava
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | flinders
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | luwingu
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | waingapu
# Processing Record 9 of Set 1 | sivaki
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | senj
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | baykit
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | yangjiang
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | mackay
# Processing Record 21 of Set 1 | olafsvik
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | bambanglipuro
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | kieta
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | meulaboh
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | the valley
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | kahului
# Processing Record 34 of Set 1 | kumluca
# Processing Record 35 of Set 1 | san cristobal
# Processing Record 36 of Set 1 | bom jesus
# Processing Record 37 of Set 1 | itoman
# Processing Record 38 of Set 1 | presidencia roque saenz pena
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | oswego
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | ginir
# Processing Record 45 of Set 1 | cabo san lucas
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | bathsheba
# Processing Record 48 of Set 1 | parkhill
# Processing Record 49 of Set 1 | dushanbe
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | marilia
# Processing Record 2 of Set 2 | mogadishu
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | nouadhibou
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | treinta y tres
# Processing Record 9 of Set 2 | bonoua
# Processing Record 10 of Set 2 | gornouralskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | oriximina
# Processing Record 12 of Set 2 | kibala
# Processing Record 13 of Set 2 | nicoya
# Processing Record 14 of Set 2 | itape
# Processing Record 15 of Set 2 | honiara
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | garowe
# Processing Record 18 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 2 | sortavala
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | kawalu
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | khovu-aksy
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | yarmouth
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | grindavik
# Processing Record 28 of Set 2 | villa maria
# Processing Record 29 of Set 2 | tilichiki
# Processing Record 30 of Set 2 | manggar
# Processing Record 31 of Set 2 | huancavelica
# Processing Record 32 of Set 2 | touros
# Processing Record 33 of Set 2 | solnechnyy
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | ivanjica
# Processing Record 36 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | altay
# Processing Record 39 of Set 2 | borgo san dalmazzo
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | padang
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | gachancipa
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | yar-sale
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | coahuayana
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | otkaznoye
# Processing Record 9 of Set 3 | nuuk
# Processing Record 10 of Set 3 | ca mau
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | plettenberg bay
# Processing Record 13 of Set 3 | bambous virieux
# Processing Record 14 of Set 3 | ancud
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | nieuw amsterdam
# Processing Record 17 of Set 3 | cap-aux-meules
# Processing Record 18 of Set 3 | necochea
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | caravelas
# Processing Record 21 of Set 3 | paris
# Processing Record 22 of Set 3 | griffith
# Processing Record 23 of Set 3 | orebro
# Processing Record 24 of Set 3 | praya
# Processing Record 25 of Set 3 | hermanus
# Processing Record 26 of Set 3 | kozloduj
# City not found. Skipping...
# Processing Record 27 of Set 3 | husavik
# Processing Record 28 of Set 3 | barraute
# Processing Record 29 of Set 3 | vao
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 3 | grand baie
# Processing Record 33 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 3 | narsaq
# Processing Record 35 of Set 3 | egvekinot
# Processing Record 36 of Set 3 | takoradi
# Processing Record 37 of Set 3 | omsukchan
# Processing Record 38 of Set 3 | mata
# Processing Record 39 of Set 3 | mount isa
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | verkhnyaya toyma
# Processing Record 42 of Set 3 | koumac
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | chiredzi
# Processing Record 45 of Set 3 | sangar
# Processing Record 46 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 3 | sao filipe
# Processing Record 48 of Set 3 | noumea
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | aklavik
# Processing Record 1 of Set 4 | hami
# Processing Record 2 of Set 4 | flin flon
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | klaksvik
# Processing Record 5 of Set 4 | komsomolskiy
# Processing Record 6 of Set 4 | opuwo
# Processing Record 7 of Set 4 | rocky mountain house
# Processing Record 8 of Set 4 | hadejia
# Processing Record 9 of Set 4 | ilulissat
# Processing Record 10 of Set 4 | dayong
# Processing Record 11 of Set 4 | copala
# Processing Record 12 of Set 4 | bluff
# Processing Record 13 of Set 4 | carnarvon
# Processing Record 14 of Set 4 | energeticheskiy
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | dzhebariki-khaya
# Processing Record 17 of Set 4 | general roca
# Processing Record 18 of Set 4 | anloga
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | shenzhen
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | cortez
# Processing Record 23 of Set 4 | qandala
# Processing Record 24 of Set 4 | bairiki
# Processing Record 25 of Set 4 | tlahualilo
# City not found. Skipping...
# Processing Record 26 of Set 4 | ishigaki
# Processing Record 27 of Set 4 | zunyi
# Processing Record 28 of Set 4 | kishapu
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | nampula
# Processing Record 31 of Set 4 | badnawar
# Processing Record 32 of Set 4 | bullhead city
# Processing Record 33 of Set 4 | rocha
# Processing Record 34 of Set 4 | mae ramat
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | angoche
# Processing Record 37 of Set 4 | rio gallegos
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | shimoda
# Processing Record 40 of Set 4 | methoni
# Processing Record 41 of Set 4 | nata
# Processing Record 42 of Set 4 | port keats
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | palmer
# Processing Record 45 of Set 4 | mumbwa
# Processing Record 46 of Set 4 | moerai
# Processing Record 47 of Set 4 | tiarei
# Processing Record 48 of Set 4 | ghanzi
# Processing Record 49 of Set 4 | paamiut
# Processing Record 50 of Set 4 | dunedin
# Processing Record 1 of Set 5 | sisimiut
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | nishihara
# Processing Record 4 of Set 5 | krasnoselkup
# Processing Record 5 of Set 5 | dikson
# Processing Record 6 of Set 5 | codrington
# Processing Record 7 of Set 5 | kruisfontein
# Processing Record 8 of Set 5 | kashi
# Processing Record 9 of Set 5 | lavrentiya
# Processing Record 10 of Set 5 | saint-georges
# Processing Record 11 of Set 5 | hay river
# Processing Record 12 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 5 | adrar
# Processing Record 14 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 5 | mehamn
# Processing Record 16 of Set 5 | comodoro rivadavia
# Processing Record 17 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint-francois
# Processing Record 19 of Set 5 | valdivia
# Processing Record 20 of Set 5 | kamenka
# Processing Record 21 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 5 | junction city
# Processing Record 23 of Set 5 | peterhead
# Processing Record 24 of Set 5 | campo grande
# Processing Record 25 of Set 5 | huarmey
# Processing Record 26 of Set 5 | acajutla
# Processing Record 27 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 5 | kaitangata
# Processing Record 29 of Set 5 | bhainsa
# Processing Record 30 of Set 5 | port macquarie
# Processing Record 31 of Set 5 | puerto escondido
# Processing Record 32 of Set 5 | fort-shevchenko
# Processing Record 33 of Set 5 | pacific grove
# Processing Record 34 of Set 5 | aykhal
# Processing Record 35 of Set 5 | talnakh
# Processing Record 36 of Set 5 | saldanha
# Processing Record 37 of Set 5 | fastiv
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | bereda
# Processing Record 40 of Set 5 | brae
# Processing Record 41 of Set 5 | dingle
# Processing Record 42 of Set 5 | deer lake
# Processing Record 43 of Set 5 | astorga
# Processing Record 44 of Set 5 | shingu
# Processing Record 45 of Set 5 | bredasdorp
# Processing Record 46 of Set 5 | atyrau
# Processing Record 47 of Set 5 | shimanovsk
# Processing Record 48 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 5 | stokmarknes
# Processing Record 50 of Set 5 | mogapi
# Processing Record 1 of Set 6 | alice springs
# Processing Record 2 of Set 6 | colac
# Processing Record 3 of Set 6 | buala
# Processing Record 4 of Set 6 | nemuro
# Processing Record 5 of Set 6 | pathein
# Processing Record 6 of Set 6 | arcos
# Processing Record 7 of Set 6 | nikolskoye
# Processing Record 8 of Set 6 | san quintin
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | okhotsk
# Processing Record 11 of Set 6 | avera
# Processing Record 12 of Set 6 | hays
# Processing Record 13 of Set 6 | itarema
# Processing Record 14 of Set 6 | sawtell
# Processing Record 15 of Set 6 | bamiantong
# Processing Record 16 of Set 6 | loreto
# Processing Record 17 of Set 6 | berdigestyakh
# Processing Record 18 of Set 6 | casma
# Processing Record 19 of Set 6 | portland
# Processing Record 20 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 6 | broome
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | uray
# Processing Record 24 of Set 6 | bam
# Processing Record 25 of Set 6 | santa cruz
# Processing Record 26 of Set 6 | port hedland
# Processing Record 27 of Set 6 | la ronge
# Processing Record 28 of Set 6 | mount gambier
# Processing Record 29 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 6 | valparaiso
# Processing Record 31 of Set 6 | saurimo
# Processing Record 32 of Set 6 | filadelfia
# Processing Record 33 of Set 6 | nantucket
# Processing Record 34 of Set 6 | beringovskiy
# Processing Record 35 of Set 6 | wanning
# Processing Record 36 of Set 6 | vardo
# Processing Record 37 of Set 6 | vuktyl
# Processing Record 38 of Set 6 | sovetskiy
# Processing Record 39 of Set 6 | rawson
# Processing Record 40 of Set 6 | paita
# Processing Record 41 of Set 6 | mpongwe
# Processing Record 42 of Set 6 | jampur
# Processing Record 43 of Set 6 | alexandria
# Processing Record 44 of Set 6 | general pico
# Processing Record 45 of Set 6 | maceio
# Processing Record 46 of Set 6 | taoudenni
# Processing Record 47 of Set 6 | bukachacha
# Processing Record 48 of Set 6 | itacoatiara
# Processing Record 49 of Set 6 | poum
# Processing Record 50 of Set 6 | bonavista
# Processing Record 1 of Set 7 | berezovyy
# Processing Record 2 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 7 | harper
# Processing Record 4 of Set 7 | matay
# Processing Record 5 of Set 7 | litoral del san juan
# City not found. Skipping...
# Processing Record 6 of Set 7 | porto santo
# Processing Record 7 of Set 7 | sorland
# Processing Record 8 of Set 7 | ryotsu
# Processing Record 9 of Set 7 | tarsus
# Processing Record 10 of Set 7 | san pedro
# Processing Record 11 of Set 7 | kautokeino
# Processing Record 12 of Set 7 | malanje
# Processing Record 13 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 7 | los llanos de aridane
# Processing Record 15 of Set 7 | san jeronimo
# Processing Record 16 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 7 | sabzevar
# Processing Record 18 of Set 7 | deputatskiy
# Processing Record 19 of Set 7 | tchollire
# Processing Record 20 of Set 7 | ust-nera
# Processing Record 21 of Set 7 | bhatkal
# Processing Record 22 of Set 7 | walvis bay
# Processing Record 23 of Set 7 | isangel
# Processing Record 24 of Set 7 | baghdad
# Processing Record 25 of Set 7 | chara
# Processing Record 26 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 7 | sakakah
# Processing Record 28 of Set 7 | makakilo city
# Processing Record 29 of Set 7 | kastamonu
# Processing Record 30 of Set 7 | oranjestad
# Processing Record 31 of Set 7 | talcahuano
# Processing Record 32 of Set 7 | chuy
# Processing Record 33 of Set 7 | anadyr
# Processing Record 34 of Set 7 | atar
# Processing Record 35 of Set 7 | lixourion
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | clyde river
# Processing Record 38 of Set 7 | arraial do cabo
# Processing Record 39 of Set 7 | yichun
# Processing Record 40 of Set 7 | chum phae
# Processing Record 41 of Set 7 | kemijarvi
# Processing Record 42 of Set 7 | ossora
# Processing Record 43 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 7 | kulhudhuffushi
# Processing Record 45 of Set 7 | yeppoon
# Processing Record 46 of Set 7 | gornopravdinsk
# Processing Record 47 of Set 7 | airai
# Processing Record 48 of Set 7 | sao joao da barra
# Processing Record 49 of Set 7 | ghogha
# Processing Record 50 of Set 7 | emerald
# Processing Record 1 of Set 8 | fort nelson
# Processing Record 2 of Set 8 | odesskoye
# Processing Record 3 of Set 8 | kabare
# Processing Record 4 of Set 8 | vredendal
# Processing Record 5 of Set 8 | carballo
# Processing Record 6 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 8 | carmelo
# Processing Record 9 of Set 8 | conde
# Processing Record 10 of Set 8 | aranos
# Processing Record 11 of Set 8 | inhambane
# Processing Record 12 of Set 8 | oranjemund
# Processing Record 13 of Set 8 | port blair
# Processing Record 14 of Set 8 | sechura
# Processing Record 15 of Set 8 | potam
# Processing Record 16 of Set 8 | sao benedito do rio preto
# Processing Record 17 of Set 8 | olinda
# Processing Record 18 of Set 8 | zaozerne
# Processing Record 19 of Set 8 | xining
# Processing Record 20 of Set 8 | zyryanka
# Processing Record 21 of Set 8 | mlandizi
# Processing Record 22 of Set 8 | aljezur
# Processing Record 23 of Set 8 | mocuba
# Processing Record 24 of Set 8 | shache
# Processing Record 25 of Set 8 | prince rupert
# Processing Record 26 of Set 8 | polewali
# Processing Record 27 of Set 8 | corinto
# Processing Record 28 of Set 8 | nome
# Processing Record 29 of Set 8 | isla vista
# Processing Record 30 of Set 8 | sri aman
# Processing Record 31 of Set 8 | blagoyevo
# Processing Record 32 of Set 8 | marsa matruh
# Processing Record 33 of Set 8 | beyla
# Processing Record 34 of Set 8 | marzuq
# Processing Record 35 of Set 8 | upernavik
# Processing Record 36 of Set 8 | dutlwe
# Processing Record 37 of Set 8 | asasa
# Processing Record 38 of Set 8 | tevriz
# Processing Record 39 of Set 8 | tiznit
# Processing Record 40 of Set 8 | kysyl-syr
# Processing Record 41 of Set 8 | zaraza
# Processing Record 42 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 43 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 8 | patea
# Processing Record 45 of Set 8 | blagodatnoye
# Processing Record 46 of Set 8 | cherskiy
# Processing Record 47 of Set 8 | hasaki
# Processing Record 48 of Set 8 | dalbandin
# Processing Record 49 of Set 8 | mudyuga
# City not found. Skipping...
# Processing Record 50 of Set 8 | vestmannaeyjar
# Processing Record 1 of Set 9 | totness
# Processing Record 2 of Set 9 | borogontsy
# Processing Record 3 of Set 9 | pauini
# Processing Record 4 of Set 9 | omboue
# Processing Record 5 of Set 9 | akureyri
# Processing Record 6 of Set 9 | amnat charoen
# Processing Record 7 of Set 9 | san carlos de bariloche
# Processing Record 8 of Set 9 | tual
# Processing Record 9 of Set 9 | hoa binh
# Processing Record 10 of Set 9 | bridlington
# Processing Record 11 of Set 9 | innisfail
# Processing Record 12 of Set 9 | charyshskoye
# Processing Record 13 of Set 9 | alofi
# Processing Record 14 of Set 9 | ballina
# Processing Record 15 of Set 9 | lebu
# Processing Record 16 of Set 9 | luxor
# Processing Record 17 of Set 9 | usinsk
# Processing Record 18 of Set 9 | marawi
# Processing Record 19 of Set 9 | dubti
# Processing Record 20 of Set 9 | burgeo
# Processing Record 21 of Set 9 | xinqing
# Processing Record 22 of Set 9 | balkhash
# Processing Record 23 of Set 9 | namibe
# Processing Record 24 of Set 9 | port lincoln
# Processing Record 25 of Set 9 | kasongo-lunda
# Processing Record 26 of Set 9 | kungurtug
# Processing Record 27 of Set 9 | tuatapere
# Processing Record 28 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 9 | santa fe
# Processing Record 30 of Set 9 | urozhayne
# City not found. Skipping...
# Processing Record 31 of Set 9 | santona
# Processing Record 32 of Set 9 | arkhangelos
# City not found. Skipping...
# Processing Record 33 of Set 9 | terrace
# Processing Record 34 of Set 9 | sanmenxia
# Processing Record 35 of Set 9 | moissala
# Processing Record 36 of Set 9 | mazagao
# Processing Record 37 of Set 9 | kyzyl-suu
# Processing Record 38 of Set 9 | beruni
# City not found. Skipping...
# Processing Record 39 of Set 9 | shagonar
# Processing Record 40 of Set 9 | dezful
# Processing Record 41 of Set 9 | almeirim
# Processing Record 42 of Set 9 | luganville
# Processing Record 43 of Set 9 | ugoofaaru
# Processing Record 44 of Set 9 | ranong
# Processing Record 45 of Set 9 | pochutla
# Processing Record 46 of Set 9 | gold coast
# Processing Record 47 of Set 9 | sitka
# Processing Record 48 of Set 9 | orange
# Processing Record 49 of Set 9 | maniitsoq
# Processing Record 50 of Set 9 | yumen
# Processing Record 1 of Set 10 | haines junction
# Processing Record 2 of Set 10 | lydenburg
# Processing Record 3 of Set 10 | duekoue
# Processing Record 4 of Set 10 | huilong
# Processing Record 5 of Set 10 | jiayuguan
# Processing Record 6 of Set 10 | iwanai
# Processing Record 7 of Set 10 | taquaritinga do norte
# Processing Record 8 of Set 10 | sept-iles
# Processing Record 9 of Set 10 | faya
# Processing Record 10 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 10 | cuiluan
# Processing Record 12 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 10 | sorong
# Processing Record 14 of Set 10 | guerrero negro
# Processing Record 15 of Set 10 | montepuez
# Processing Record 16 of Set 10 | anapskaya
# Processing Record 17 of Set 10 | porto velho
# Processing Record 18 of Set 10 | ekibastuz
# Processing Record 19 of Set 10 | port moresby
# Processing Record 20 of Set 10 | vung tau
# Processing Record 21 of Set 10 | frydlant
# Processing Record 22 of Set 10 | kamyaran
# Processing Record 23 of Set 10 | kurilsk
# Processing Record 24 of Set 10 | tabulbah
# City not found. Skipping...
# Processing Record 25 of Set 10 | tigil
# Processing Record 26 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 10 | camalu
# Processing Record 28 of Set 10 | berlevag
# Processing Record 29 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 10 | izvestkovyy
# Processing Record 31 of Set 10 | westport
# Processing Record 32 of Set 10 | pershotravneve
# Processing Record 33 of Set 10 | faanui
# Processing Record 34 of Set 10 | jalu
# Processing Record 35 of Set 10 | caohai
# Processing Record 36 of Set 10 | kiunga
# Processing Record 37 of Set 10 | longyearbyen
# Processing Record 38 of Set 10 | charters towers
# Processing Record 39 of Set 10 | bombay
# Processing Record 40 of Set 10 | lockport
# Processing Record 41 of Set 10 | porto novo
# Processing Record 42 of Set 10 | picayune
# Processing Record 43 of Set 10 | buncrana
# Processing Record 44 of Set 10 | takhtamygda
# Processing Record 45 of Set 10 | thunder bay
# Processing Record 46 of Set 10 | san juan
# Processing Record 47 of Set 10 | orlik
# Processing Record 48 of Set 10 | tourlaville
# Processing Record 49 of Set 10 | oromocto
# Processing Record 50 of Set 10 | remanso
# Processing Record 1 of Set 11 | high level
# Processing Record 2 of Set 11 | salihorsk
# Processing Record 3 of Set 11 | karratha
# Processing Record 4 of Set 11 | douglas
# Processing Record 5 of Set 11 | port hardy
# Processing Record 6 of Set 11 | boyolangu
# Processing Record 7 of Set 11 | biak
# Processing Record 8 of Set 11 | urengoy
# Processing Record 9 of Set 11 | mabaruma
# Processing Record 10 of Set 11 | tandalti
# Processing Record 11 of Set 11 | ewa beach
# Processing Record 12 of Set 11 | kuusamo
# Processing Record 13 of Set 11 | praia
# Processing Record 14 of Set 11 | shangzhi
# Processing Record 15 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 16 of Set 11 | nadym
# Processing Record 17 of Set 11 | davidson
# Processing Record 18 of Set 11 | akyab
# Processing Record 19 of Set 11 | diffa
# Processing Record 20 of Set 11 | ler
# Processing Record 21 of Set 11 | victoria
# Processing Record 22 of Set 11 | punta alta
# Processing Record 23 of Set 11 | belaya gora
# Processing Record 24 of Set 11 | bara
# Processing Record 25 of Set 11 | bhainsdehi
# Processing Record 26 of Set 11 | meadow lake
# Processing Record 27 of Set 11 | phek
# Processing Record 28 of Set 11 | taltal
# Processing Record 29 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 11 | lorengau
# Processing Record 31 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 11 | jiamusi
# Processing Record 33 of Set 11 | puerto el triunfo
# Processing Record 34 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 36 of Set 11 | cockburn town
# Processing Record 37 of Set 11 | burica
# City not found. Skipping...
# Processing Record 38 of Set 11 | hashtrud
# Processing Record 39 of Set 11 | mgandu
# Processing Record 40 of Set 11 | buin
# Processing Record 41 of Set 11 | yanam
# Processing Record 42 of Set 11 | pasighat
# Processing Record 43 of Set 11 | rosarito
# Processing Record 44 of Set 11 | maloy
# Processing Record 45 of Set 11 | norilsk
# Processing Record 46 of Set 11 | catio
# Processing Record 47 of Set 11 | nizwa
# Processing Record 48 of Set 11 | kutum
# Processing Record 49 of Set 11 | lensk
# Processing Record 50 of Set 11 | sangin
# Processing Record 1 of Set 12 | maumere
# Processing Record 2 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 3 of Set 12 | sarakhs
# Processing Record 4 of Set 12 | bjornevatn
# Processing Record 5 of Set 12 | biltine
# Processing Record 6 of Set 12 | gongzhuling
# Processing Record 7 of Set 12 | dicabisagan
# Processing Record 8 of Set 12 | gannan
# Processing Record 9 of Set 12 | batagay-alyta
# Processing Record 10 of Set 12 | roald
# Processing Record 11 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 12 | kosa
# Processing Record 13 of Set 12 | orsha
# Processing Record 14 of Set 12 | rathdrum
# Processing Record 15 of Set 12 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 16 of Set 12 | luwuk
# Processing Record 17 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 12 | kitui
# Processing Record 19 of Set 12 | saint marys
# Processing Record 20 of Set 12 | williams lake
# Processing Record 21 of Set 12 | arifwala
# Processing Record 22 of Set 12 | sosnovo-ozerskoye
# Processing Record 23 of Set 12 | tongzi
# Processing Record 24 of Set 12 | hornbaek
# Processing Record 25 of Set 12 | nhulunbuy
# Processing Record 26 of Set 12 | half moon bay
# Processing Record 27 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 28 of Set 12 | huinan
# Processing Record 29 of Set 12 | bandarbeyla
# Processing Record 30 of Set 12 | diego de almagro
# Processing Record 31 of Set 12 | vila franca do campo
# Processing Record 32 of Set 12 | ajdabiya
# Processing Record 33 of Set 12 | nyurba
# Processing Record 34 of Set 12 | arona
# Processing Record 35 of Set 12 | port-gentil
# Processing Record 36 of Set 12 | bandar penggaram
# City not found. Skipping...
# Processing Record 37 of Set 12 | barcelos
# Processing Record 38 of Set 12 | evensk
# Processing Record 39 of Set 12 | atasu
# Processing Record 40 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 12 | hirara
# Processing Record 42 of Set 12 | sai buri
# Processing Record 43 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 44 of Set 12 | moron
# Processing Record 45 of Set 12 | pafos
# Processing Record 46 of Set 12 | sobolevo
# Processing Record 47 of Set 12 | luena
# Processing Record 48 of Set 12 | ketchikan
# Processing Record 49 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 12 | dupnica
# City not found. Skipping...
# Processing Record 1 of Set 13 | madang
# Processing Record 2 of Set 13 | cabedelo
# Processing Record 3 of Set 13 | pong
# Processing Record 4 of Set 13 | dudinka
# Processing Record 5 of Set 13 | podor
# Processing Record 6 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 7 of Set 13 | praia da vitoria
# Processing Record 8 of Set 13 | matehuala
# Processing Record 9 of Set 13 | akcakoca
# Processing Record 10 of Set 13 | hervey bay
# Processing Record 11 of Set 13 | buraydah
# Processing Record 12 of Set 13 | laguna
# Processing Record 13 of Set 13 | golden gate
# Processing Record 14 of Set 13 | pangnirtung
# Processing Record 15 of Set 13 | kollam
# Processing Record 16 of Set 13 | dibulla
# Processing Record 17 of Set 13 | carutapera
# Processing Record 18 of Set 13 | sao jose da coroa grande
# Processing Record 19 of Set 13 | bol
# Processing Record 20 of Set 13 | fukue
# Processing Record 21 of Set 13 | hofn
# Processing Record 22 of Set 13 | erzin
# Processing Record 23 of Set 13 | bodden town
# Processing Record 24 of Set 13 | la sarre
# Processing Record 25 of Set 13 | skoropuskovskiy
# Processing Record 26 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 13 | bubaque
# Processing Record 28 of Set 13 | chegdomyn
# Processing Record 29 of Set 13 | bibiani
# Processing Record 30 of Set 13 | stryn
# Processing Record 31 of Set 13 | basco
# Processing Record 32 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 13 | hambantota
# Processing Record 34 of Set 13 | shush
# Processing Record 35 of Set 13 | guaymas
# Processing Record 36 of Set 13 | salvacion
# Processing Record 37 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 13 | jaisalmer
# Processing Record 39 of Set 13 | hualmay
# Processing Record 40 of Set 13 | medicine hat
# Processing Record 41 of Set 13 | sao joao dos patos
# Processing Record 42 of Set 13 | yarada
# Processing Record 43 of Set 13 | lalitpur
# Processing Record 44 of Set 13 | tura
# Processing Record 45 of Set 13 | manokwari
# Processing Record 46 of Set 13 | darhan
# Processing Record 47 of Set 13 | gamba
# Processing Record 48 of Set 13 | lagoa
# Processing Record 49 of Set 13 | ocampo
# Processing Record 50 of Set 13 | tezu
# Processing Record 1 of Set 14 | moranbah
# Processing Record 2 of Set 14 | nargana
# Processing Record 3 of Set 14 | zhezkazgan
# Processing Record 4 of Set 14 | barra do garcas
# Processing Record 5 of Set 14 | caninde
# Processing Record 6 of Set 14 | waki
# Processing Record 7 of Set 14 | sistranda
# Processing Record 8 of Set 14 | kuchurhan
# Processing Record 9 of Set 14 | sirpur
# Processing Record 10 of Set 14 | agva
# City not found. Skipping...
# Processing Record 11 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 14 | san rafael
# Processing Record 14 of Set 14 | winnemucca
# Processing Record 15 of Set 14 | muscat
# Processing Record 16 of Set 14 | mitzic
# Processing Record 17 of Set 14 | leningradskiy
# Processing Record 18 of Set 14 | bonen
# Processing Record 19 of Set 14 | tomari
# Processing Record 20 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 14 | kirakira
# Processing Record 22 of Set 14 | luangwa
# Processing Record 23 of Set 14 | stornoway
# Processing Record 24 of Set 14 | gobabis
# Processing Record 25 of Set 14 | vila velha
# Processing Record 26 of Set 14 | tupik
# Processing Record 27 of Set 14 | chapais
# Processing Record 28 of Set 14 | vryburg
# Processing Record 29 of Set 14 | guerrero
# Processing Record 30 of Set 14 | tabuk
# Processing Record 31 of Set 14 | tautira
# Processing Record 32 of Set 14 | tazovskiy
# Processing Record 33 of Set 14 | blyth
# Processing Record 34 of Set 14 | borujerd
# Processing Record 35 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 14 | pierre
# Processing Record 37 of Set 14 | boralday
# Processing Record 38 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 14 | sungaipenuh
# Processing Record 40 of Set 14 | yeniseysk
# Processing Record 41 of Set 14 | issia
# Processing Record 42 of Set 14 | havre-saint-pierre
# Processing Record 43 of Set 14 | tuy hoa
# Processing Record 44 of Set 14 | negombo
# Processing Record 45 of Set 14 | gilbues
# Processing Record 46 of Set 14 | lere
# Processing Record 47 of Set 14 | bainbridge
# Processing Record 48 of Set 14 | victoria point
# Processing Record 49 of Set 14 | grand forks
# Processing Record 50 of Set 14 | ystad
# Processing Record 1 of Set 15 | warin chamrap
# Processing Record 2 of Set 15 | urumqi
# Processing Record 3 of Set 15 | madanapalle
# Processing Record 4 of Set 15 | roma
# Processing Record 5 of Set 15 | udimskiy
# Processing Record 6 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 7 of Set 15 | zhigansk
# Processing Record 8 of Set 15 | kavaratti
# Processing Record 9 of Set 15 | kenai
# Processing Record 10 of Set 15 | zvishavane
# Processing Record 11 of Set 15 | pervomayskoye
# Processing Record 12 of Set 15 | debre tabor
# Processing Record 13 of Set 15 | zhangjiakou
# Processing Record 14 of Set 15 | sotouboua
# Processing Record 15 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 15 | polunochnoye
# Processing Record 17 of Set 15 | pa sang
# Processing Record 18 of Set 15 | bilibino
# Processing Record 19 of Set 15 | goderich
# Processing Record 20 of Set 15 | nelson bay
# Processing Record 21 of Set 15 | mayo
# Processing Record 22 of Set 15 | gillette
# Processing Record 23 of Set 15 | salina cruz
# Processing Record 24 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 25 of Set 15 | yuci
# Processing Record 26 of Set 15 | uruguaiana
# Processing Record 27 of Set 15 | balkanabat
# Processing Record 28 of Set 15 | ostrovnoy
# Processing Record 29 of Set 15 | kvareli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Constantine      DZ  36.3650    6.6147     36.81        87           0
# 1      Morondava      MG -20.2833   44.2833     78.64        89          23
# 2  Mar Del Plata      AR -38.0023  -57.5575     60.87        78           0
# 3       Flinders      AU -34.5833  150.8552     84.18        62          94
# 4        Luwingu      ZM -10.2621   29.9271     61.45        97         100
# 5         Atuona      PF  -9.8000 -139.0333     77.31        80          22
# 6       Waingapu      ID  -9.6567  120.2641     85.53        67          80
# 7         Sivaki      RU  52.6333  126.7500     10.00        85         100
# 8        Mataura      NZ -46.1927  168.8643     70.90        39         100
# 9           Senj      HR  44.9894   14.9058     35.73        96          74
#
#    Wind Speed Current Description
# 0        0.00           clear sky
# 1        8.14          few clouds
# 2        8.99           clear sky
# 3        5.99     overcast clouds
# 4        7.11          light rain
# 5       13.73          light rain
# 6       10.69       broken clouds
# 7        5.73     overcast clouds
# 8        5.77     overcast clouds
# 9        3.89       broken clouds

# %%
output_data_file = "WeatherPy_Database.csv"
